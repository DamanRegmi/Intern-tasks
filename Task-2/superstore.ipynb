# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
data=pd.read_csv('Sample - Superstore.csv',encoding="latin1")
print(data.head(20))
# Out:
#     Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0        1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1        2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2        3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3        4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4        5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 5        6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 6        7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 7        8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 8        9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 9       10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 10      11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 11      12  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 12      13  CA-2017-114412   4/15/2017   4/20/2017  Standard Class
# ...

# %%
customer_columns=['Customer ID','Customer Name','Segment','Country']
product_columns=['Product ID','Category','Sub-Category','Product Name']
order_column=['Order ID','Order Date', 'Ship Date']
shipmode_columns = ['Ship Mode']
sales_columns=['Customer ID', 'Product ID', 'Order ID', 'Ship Mode','Sales', 'Quantity', 'Discount', 'Profit']

# %%
customer_table = data[customer_columns].drop_duplicates()
product_table=data[product_columns].drop_duplicates()
order_table=data[order_column].drop_duplicates()
shipmode_table=data[shipmode_columns].drop_duplicates()
sale_table=data[sales_columns].drop_duplicates()

# %%
customer_table.to_csv('cutomer.csv',index=False)
product_table.to_csv('product.csv', index=False)
order_table.to_csv('order.csv', index=False)
shipmode_table.to_csv('shipmode.csv', index=False)
sale_table.to_csv('sale.csv',index=False)

# %%
pd.read_csv('sale.csv')
# Out:
#      Customer ID       Product ID        Order ID       Ship Mode     Sales  \
# 0       CG-12520  FUR-BO-10001798  CA-2016-152156    Second Class  261.9600
# 1       CG-12520  FUR-CH-10000454  CA-2016-152156    Second Class  731.9400
# 2       DV-13045  OFF-LA-10000240  CA-2016-138688    Second Class   14.6200
# 3       SO-20335  FUR-TA-10000577  US-2015-108966  Standard Class  957.5775
# 4       SO-20335  OFF-ST-10000760  US-2015-108966  Standard Class   22.3680
# ...          ...              ...             ...             ...       ...
# 9988    TB-21400  FUR-FU-10001889  CA-2014-110422    Second Class   25.2480
# 9989    DB-13060  FUR-FU-10000747  CA-2017-121258  Standard Class   91.9600
# 9990    DB-13060  TEC-PH-10003645  CA-2017-121258  Standard Class  258.5760
# 9991    DB-13060  OFF-PA-10004041  CA-2017-121258  Standard Class   29.6000
# 9992    CC-12220  OFF-AP-10002684  CA-2017-119914    Second Class  243.1600
#
#       Quantity  Discount    Profit
# ...

# %%
pip install graphviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 696.9 kB/s eta 0:00:000:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from graphviz import Digraph

# Create a Graphviz Digraph for the ERD
erd = Digraph('ERD', format='png')

# Add nodes for each table
erd.node('Customer', 'Customer\n(Customer ID, Customer Name, Segment,Country)')
erd.node('Product', 'Product\n(Product ID, Category, Sub-Category, Product Name)')
erd.node('Order', 'Order\n(Order ID, Order Date, Ship Date)')
erd.node('ShipMode', 'ShipMode\n(Ship Mode)')
erd.node('Sales', 'Sales\n(Customer ID, Product ID, Order ID, Ship Mode, Sale, Quantity, Discount, Profit)')

# Define relationships between tables
erd.edge('Customer', 'Sales', label='Customer_ID')
erd.edge('Product', 'Sales', label='Product_ID')
erd.edge('Order', 'Sales', label='Order_ID')
erd.edge('ShipMode', 'Sales', label='Ship_Mode')

# Render the ERD to a file
erd.render('normalized_erd')
print("ERD saved as normalized_erd.png")
# Out:
# ERD saved as normalized_erd.png
